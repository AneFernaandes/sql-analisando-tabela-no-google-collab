# %% [markdown]
# <a href="https://colab.research.google.com/github/AneFernaandes/sql-analisando-tabela-no-google-collab/blob/main/sql_analisando_tabela.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fazendo consultas SQL
# Notas de Estudo

# %%
#importando bibliotecas e conectando o banco de dados
import sqlite3
import pandas as pd
conn = sqlite3.connect("database.db")

# %%
#consulta dos dados no banco de dados
consulta_atividade= "SELECT * FROM flight_activity LIMIT 10"
df_atividade = pd.read_sql_query(consulta_atividade, conn)

# %%
#fechando a conexão com o banco de dados
# conn.close()

# %%
df_atividade.head()
# Out:
#    loyalty_number  year  month  flights_booked  flights_with_companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    total_flights  distance  points_accumulated  points_redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    dollar_cost_points_redeemed
# 0                            0
# 1                            0
# 2                            0
# ...

# %% [markdown]
# ### Cuidados importantes!
#
# 1. A última linha do SELECT, NÃO TEM VÍRGULA!.
# 2. Obrigatório NOMEAR A TABELA!.
# 3. Sempre INDICAR A TABELA FONTE da qual a coluna está sendo extraída.
# 4. As strings são INDICADAS POR ASPAS SIMPLES.
# 5. O símbolo de * indica TODAS AS COLUNAS

# %% [markdown]
# #  Coletando dados do banco de dados
#  1. Selecione as colunas: loyalty_number, year, month, flights_booked, total_flights, distance e points_accumulated da tabela “flight_activity”

# %%
#sempre utilizar 3 aspas para usar o SELECT FROM WHERE no Collab
consulta_atividade= """

    SELECT
    loyalty_number,
    year,
    month,
    flights_booked,
    total_flights,
    distance,
    points_accumulated


    FROM
    flight_activity


"""
df_atividade = pd.read_sql_query(consulta_atividade, conn)

df_atividade.head()
# Out:
#    loyalty_number  year  month  flights_booked  total_flights  distance  \
# 0          100018  2017      1               3              3      1521
# 1          100102  2017      1              10             14      2030
# 2          100140  2017      1               6              6      1200
# 3          100214  2017      1               0              0         0
# 4          100272  2017      1               0              0         0
#
#    points_accumulated
# 0               152.0
# 1               203.0
# 2               120.0
# 3                 0.0
# 4                 0.0

# %% [markdown]
#   2.  Selecione as mesmas colunas, porém, recupere somente as linhas cuja coluna distance é maior do que 2000, da tabela“flight_activity”

# %%
consulta_atividade = """

  SELECT
    fa.loyalty_number,
    fa.year,
    fa.month,
    fa.flights_booked,
    fa.total_flights,
    fa.distance,
    fa.points_accumulated

  FROM
    flight_activity fa
  WHERE
    distance < 2000

 """
df_atividade = pd.read_sql_query(consulta_atividade, conn)
df_atividade.head()
# Out:
#    loyalty_number  year  month  flights_booked  total_flights  distance  \
# 0          100018  2017      1               3              3      1521
# 1          100140  2017      1               6              6      1200
# 2          100214  2017      1               0              0         0
# 3          100272  2017      1               0              0         0
# 4          100301  2017      1               0              0         0
#
#    points_accumulated
# 0               152.0
# 1               120.0
# 2                 0.0
# 3                 0.0
# 4                 0.0

# %% [markdown]
# # Exercícios da Aula 01
#
# 1. Selecione as colunas: loyalty_number, country, city, gender e loyalty_card, salary da tabela “flight_loyalty_history”.

# %%
consulta_atividade = """

  SELECT
    flh.loyalty_number,
    flh.country,
    flh.city,
    flh.gender,
    flh.loyalty_card,
    flh.salary



  FROM
    flight_loyalty_history flh


"""

df_atividade = pd.read_sql_query(consulta_atividade, conn)
df_atividade.head()
# Out:
#    loyalty_number country       city  gender loyalty_card    salary
# 0          480934  Canada    Toronto  Female         Star   83236.0
# 1          549612  Canada   Edmonton    Male         Star       NaN
# 2          429460  Canada  Vancouver    Male         Star       NaN
# 3          608370  Canada    Toronto    Male         Star       NaN
# 4          530508  Canada       Hull    Male         Star  103495.0

# %% [markdown]
# 2. Selecione as mesmas colunas, porém, recupere somente as linhas cuja coluna gender é igual a Female da tabela
# “flight_loyalty_history”.

# %%
consulta_atividade = """

  SELECT
    flh.loyalty_number,
    flh.country,
    flh.city,
    flh.gender,
    flh.loyalty_card,
    flh.salary

  FROM
    flight_loyalty_history flh
  WHERE
    gender = 'Female'


"""
df_atividade = pd.read_sql_query(consulta_atividade, conn)
df_atividade.head()
# Out:
#    loyalty_number country          city  gender loyalty_card    salary
# 0          480934  Canada       Toronto  Female         Star   83236.0
# 1          927943  Canada       Toronto  Female         Star       NaN
# 2          852392  Canada      Montreal  Female         Star  100159.0
# 3          932823  Canada     Vancouver  Female         Star   66444.0
# 4          144514  Canada  Dawson Creek  Female         Star   49618.0

# %% [markdown]
# 3. Selecione as colunas: loyalty_number, month, year, distance, flights_booked e total_flights da tabela “flight_activity”, e
# recupere somente as linhas cuja coluna “flights_booked” é maior do que 10 e a coluna “flights_booked” é menor do que 12, da tabela “flight_activity”

# %%
consulta_atividade = """

  SELECT
    fa.loyalty_number,
    fa.month,
    fa.year,
    fa.distance,
    fa.flights_booked,
    fa.total_flights


  FROM
    flight_activity fa
  WHERE
    fa.flights_booked > 10 AND fa.flights_booked < 12


 """

df_atividade = pd.read_sql_query(consulta_atividade, conn)
df_atividade.head()
# Out:
#    loyalty_number  month  year  distance  flights_booked  total_flights
# 0          100727      1  2017      1144              11             11
# 1          100883      1  2017      3124              11             11
# 2          101515      1  2017      1100              11             11
# 3          101594      1  2017      3399              11             11
# 4          104353      1  2017      1343              11             17
